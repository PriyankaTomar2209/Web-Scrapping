# %%
#import reqiured module
import requests
from bs4 import Beautifulsoup
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6edccf49098c> in <module>
#       1 import requests
# ----> 2 import Beautifulsoup
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'Beautifulsoup'

# %%
#create a variable ith url
url = 'https://en.wikipedia.org/wiki/List_of_A_Song_of_Ice_and_Fire_characters'

# %%
#scrape the html at the url
r = request.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cdcb9fef040a> in <module>
#       1 #scrape the html at the url
# ----> 2 r = request.get(url)
#
# NameError: name 'request' is not defined
